# %%
import pandas as pd
import numpy as np
import ExMAS
import ExMAS.main
import ExMAS.utils
import pprint
import itertools
import csv
import os
import osmnx as ox
import dotmap
import sys
import random
import time
import math
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [16, 16]

import networkx as nx #graphs
cwd = os.getcwd()

from ExMAS.utils import inData as inData
from dotmap import DotMap

# %%
# df1 = pd.read_csv('City_requests.csv') #demografia Wzgórza Krzesławickie
# df = df1.loc[df1.index.repeat(df1.ogolem)].reset_index(drop=True) #repeat Rows N times (equal "ogolem"): N Rows = N people 

# params = ExMAS.utils.get_config('default_SUM.json') # load the default
# params.city = 'Krakow, Poland'
# params = ExMAS.utils.make_paths(params) # update file paths

# inData = ExMAS.utils.load_G(inData, params, stats=True)  # download the graph
# frac = 0.2
# params.shared_discount = 0.3
# params.nP = int(frac * len(df))
# params.simTime = 0.5
# params.t0 = params.t0.replace(hour=8)
# params.speeds.ride = 6
# params.VoT = 0.003
# params.price = 1.5
# sample = df.sample(n = int(frac * len(df)), replace=False, weights=None, random_state=None, axis=None) # demand of RP=frac*population
# sample['origin'] = sample.apply(lambda row:  ox.get_nearest_node(inData.G, (row['y'], row['x'])), axis = 1) 

# inData = ExMAS.utils.generate_demand(inData, params) #generate trip requests

# my_requests = inData.requests
# my_requests.destination = ox.get_nearest_node(inData.G,[50.09516, 20.06522])
# my_requests["origin"] = sample.origin.values

# my_requests['dist'] = my_requests.apply(lambda request: inData.skim.loc[request.origin, request.destination], axis=1)

# my_requests['ttrav'] = my_requests.apply(lambda request: pd.Timedelta(request.dist, 's').floor('s'), axis=1)
# #my_requests.ttrav = (pd.to_timedelta(my_requests.ttrav) / params.speeds.ride).dt.floor('1s')
# my_requests.tarr = [request.treq + request.ttrav for _, request in my_requests.iterrows()]
# my_requests = inData.requests
# inData.requests = my_requests
# # inData.requests.to_csv("check.csv")

# inData = ExMAS.main(inData, params)

# KPIs = inData.sblts.res.to_frame()[:23]
# KPIs['description']  = ExMAS.utils.KPIs_descriptions
# KPIs.columns = ['KPI', 'description']
# KPIs
# # KPIs.to_csv("KPIs022.csv")

# %%
df1 = pd.read_csv('City_requests.csv') #demografia Wzgórza Krzesławickie
df = df1.loc[df1.index.repeat(df1.ogolem)].reset_index(drop=True) #repeat Rows N times (equal "ogolem"): N Rows = N people 
params = ExMAS.utils.get_config('default_SUM.json') # load the default
params.city = 'Krakow, Poland'
params = ExMAS.utils.make_paths(params) # update file paths
inData = ExMAS.utils.load_G(inData, params, stats=True)  # download the graph

# %%
def run_ExMAS_SUM(inData, params, hub, frac, repl):

    params.nP = int(frac * len(df))
    sample = df.sample(n = int(frac * len(df)), replace=False, weights=None, random_state=None, axis=None) # demand of RP=frac*population
    sample['origin'] = sample.apply(lambda row:  ox.get_nearest_node(inData.G, (row['y'], row['x'])), axis = 1) 
    inData = ExMAS.utils.generate_demand(inData, params) #generate trip requests

    my_requests = inData.requests
    my_requests.destination = hub[1]
    my_requests["origin"] = sample.origin.values
    my_requests['dist'] = my_requests.apply(lambda request: inData.skim.loc[request.origin, request.destination], axis=1)
    my_requests['ttrav'] = my_requests.apply(lambda request: pd.Timedelta(request.dist, 's').floor('s'), axis=1)
    my_requests.tarr = [request.treq + request.ttrav for _, request in my_requests.iterrows()]
    my_requests = inData.requests
    inData.requests = my_requests
    # inData.requests.to_csv("check.csv")
    inData = ExMAS.main(inData, params)
    KPIs = inData.sblts.res.to_frame()[:23]
    # KPIs['description']  = ExMAS.utils.KPIs_descriptions
    KPIs.columns = ['KPI']
    KPIs
    KPIs.to_csv(f'KPI_{hub[0]}_{frac}_{repl}.csv') #res/
    return KPIs



params.shared_discount = 0.2
params.simTime = 0.5
params.t0 = params.t0.replace(hour=8)
params.speeds.ride = 6
params.VoT = 0.003
params.price = 1.5
results = dict()
 
hubs = [('hub1', ox.get_nearest_node(inData.G,[50.09516, 20.06522])),   #list of hubs
        ('hub2', ox.get_nearest_node(inData.G,[50.09203901, 20.07409523]))]

for frac in  [0.0005, 0.001, 0.0015, 0.002, 0.003, 0.005, 0.007, 0.008, 0.009, 0.01]: #list of frac 0.003, 0.005, 0.007, 0.009, 0.01
    for h in hubs:
        for i in range(10): 
            print(h[0], frac, i + 1)
            results[frac] = run_ExMAS_SUM(inData, params, h, frac, i)
# Out:
# hub1 0.0005 1
# 18-01-24 13:05:27-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:27-INFO-creating combinations
# 18-01-24 13:05:27-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:27-INFO-Degree 2 	Completed
# 18-01-24 13:05:27-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:27-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:27-INFO-Problem solution: Optimal.
# Total costs for single trips:            270
# reduced by matching to:                  270
# 18-01-24 13:05:27-INFO-Calculations  completed
# 18-01-24 13:05:27-INFO-DotMap(VehHourTrav=270, VehHourTrav_ns=270, PassHourTrav=270, PassHourTrav_ns=270, PassUtility=3.2445, PassUtility_ns=3.2445, mean_lambda=nan, revenue_s=324.0, revenue_ns=405.0, Fare_Discount=-0.2, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 2
# 18-01-24 13:05:28-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:28-INFO-creating combinations
# 18-01-24 13:05:28-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:28-INFO-Degree 2 	Completed
# 18-01-24 13:05:28-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:28-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:28-INFO-Problem solution: Optimal.
# Total costs for single trips:            198
# reduced by matching to:                  198
# 18-01-24 13:05:28-INFO-Calculations  completed
# 18-01-24 13:05:28-INFO-DotMap(VehHourTrav=198, VehHourTrav_ns=198, PassHourTrav=198, PassHourTrav_ns=198, PassUtility=2.376, PassUtility_ns=2.376, mean_lambda=nan, revenue_s=237.60000000000002, revenue_ns=297.0, Fare_Discount=-0.19999999999999993, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 3
# 18-01-24 13:05:28-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:28-INFO-creating combinations
# 18-01-24 13:05:28-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:28-INFO-Degree 2 	Completed
# 18-01-24 13:05:28-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:28-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:28-INFO-Problem solution: Optimal.
# Total costs for single trips:            114
# reduced by matching to:                  114
# 18-01-24 13:05:28-INFO-Calculations  completed
# 18-01-24 13:05:28-INFO-DotMap(VehHourTrav=114, VehHourTrav_ns=114, PassHourTrav=114, PassHourTrav_ns=114, PassUtility=1.368, PassUtility_ns=1.368, mean_lambda=nan, revenue_s=136.8, revenue_ns=171.0, Fare_Discount=-0.19999999999999993, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 4
# 18-01-24 13:05:28-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:28-INFO-creating combinations
# 18-01-24 13:05:28-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:28-INFO-Degree 2 	Completed
# 18-01-24 13:05:28-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:28-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:28-INFO-Problem solution: Optimal.
# Total costs for single trips:            333
# reduced by matching to:                  333
# 18-01-24 13:05:28-INFO-Calculations  completed
# 18-01-24 13:05:28-INFO-DotMap(VehHourTrav=333, VehHourTrav_ns=333, PassHourTrav=333, PassHourTrav_ns=333, PassUtility=3.9975, PassUtility_ns=3.9975, mean_lambda=nan, revenue_s=399.6, revenue_ns=499.5, Fare_Discount=-0.19999999999999996, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 5
# 18-01-24 13:05:29-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:29-INFO-creating combinations
# 18-01-24 13:05:29-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:29-INFO-Degree 2 	Completed
# 18-01-24 13:05:29-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:29-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:29-INFO-Problem solution: Optimal.
# Total costs for single trips:            198
# reduced by matching to:                  198
# 18-01-24 13:05:29-INFO-Calculations  completed
# 18-01-24 13:05:29-INFO-DotMap(VehHourTrav=198, VehHourTrav_ns=198, PassHourTrav=198, PassHourTrav_ns=198, PassUtility=2.376, PassUtility_ns=2.376, mean_lambda=nan, revenue_s=237.60000000000002, revenue_ns=297.0, Fare_Discount=-0.19999999999999993, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 6
# 18-01-24 13:05:29-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:29-INFO-creating combinations
# 18-01-24 13:05:29-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:29-INFO-Degree 2 	Completed
# 18-01-24 13:05:29-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:29-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:29-INFO-Problem solution: Optimal.
# Total costs for single trips:            296
# reduced by matching to:                  296
# 18-01-24 13:05:29-INFO-Calculations  completed
# 18-01-24 13:05:29-INFO-DotMap(VehHourTrav=296, VehHourTrav_ns=296, PassHourTrav=296, PassHourTrav_ns=296, PassUtility=3.5595, PassUtility_ns=3.5595, mean_lambda=nan, revenue_s=355.20000000000005, revenue_ns=444.0, Fare_Discount=-0.1999999999999999, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 7
# 18-01-24 13:05:29-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:29-INFO-creating combinations
# 18-01-24 13:05:29-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:29-INFO-Degree 2 	Completed
# 18-01-24 13:05:29-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:29-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:29-INFO-Problem solution: Optimal.
# Total costs for single trips:            283
# reduced by matching to:                  283
# 18-01-24 13:05:29-INFO-Calculations  completed
# 18-01-24 13:05:29-INFO-DotMap(VehHourTrav=283, VehHourTrav_ns=283, PassHourTrav=283, PassHourTrav_ns=283, PassUtility=3.4035, PassUtility_ns=3.4035, mean_lambda=nan, revenue_s=339.6, revenue_ns=424.5, Fare_Discount=-0.19999999999999996, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 8
# 18-01-24 13:05:30-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:30-INFO-creating combinations
# 18-01-24 13:05:30-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:30-INFO-Degree 2 	Completed
# 18-01-24 13:05:30-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:30-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:30-INFO-Problem solution: Optimal.
# Total costs for single trips:            198
# reduced by matching to:                  198
# 18-01-24 13:05:30-INFO-Calculations  completed
# 18-01-24 13:05:30-INFO-DotMap(VehHourTrav=198, VehHourTrav_ns=198, PassHourTrav=198, PassHourTrav_ns=198, PassUtility=2.376, PassUtility_ns=2.376, mean_lambda=nan, revenue_s=237.60000000000002, revenue_ns=297.0, Fare_Discount=-0.19999999999999993, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 9
# 18-01-24 13:05:30-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:30-INFO-creating combinations
# 18-01-24 13:05:30-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:30-INFO-Degree 2 	Completed
# 18-01-24 13:05:30-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:30-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:30-INFO-Problem solution: Optimal.
# Total costs for single trips:            114
# reduced by matching to:                  114
# 18-01-24 13:05:30-INFO-Calculations  completed
# 18-01-24 13:05:30-INFO-DotMap(VehHourTrav=114, VehHourTrav_ns=114, PassHourTrav=114, PassHourTrav_ns=114, PassUtility=1.368, PassUtility_ns=1.368, mean_lambda=nan, revenue_s=136.8, revenue_ns=171.0, Fare_Discount=-0.19999999999999993, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0005 10
# 18-01-24 13:05:30-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:30-INFO-creating combinations
# 18-01-24 13:05:30-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:30-INFO-Degree 2 	Completed
# 18-01-24 13:05:30-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:30-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:30-INFO-Problem solution: Optimal.
# Total costs for single trips:            205
# reduced by matching to:                  205
# 18-01-24 13:05:30-INFO-Calculations  completed
# 18-01-24 13:05:30-INFO-DotMap(VehHourTrav=205, VehHourTrav_ns=205, PassHourTrav=205, PassHourTrav_ns=205, PassUtility=2.4615, PassUtility_ns=2.4615, mean_lambda=nan, revenue_s=246.0, revenue_ns=307.5, Fare_Discount=-0.2, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 1
# 18-01-24 13:05:31-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:31-INFO-creating combinations
# 18-01-24 13:05:31-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:31-INFO-Degree 2 	Completed
# 18-01-24 13:05:31-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:31-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:31-INFO-Problem solution: Optimal.
# Total costs for single trips:            283
# reduced by matching to:                  283
# 18-01-24 13:05:31-INFO-Calculations  completed
# 18-01-24 13:05:31-INFO-DotMap(VehHourTrav=283, VehHourTrav_ns=283, PassHourTrav=283, PassHourTrav_ns=283, PassUtility=3.402, PassUtility_ns=3.402, mean_lambda=nan, revenue_s=339.6, revenue_ns=424.5, Fare_Discount=-0.19999999999999996, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 2
# 18-01-24 13:05:31-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:31-INFO-creating combinations
# 18-01-24 13:05:31-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:31-INFO-Degree 2 	Completed
# 18-01-24 13:05:31-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:31-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:31-INFO-Problem solution: Optimal.
# Total costs for single trips:            212
# reduced by matching to:                  212
# 18-01-24 13:05:31-INFO-Calculations  completed
# 18-01-24 13:05:31-INFO-DotMap(VehHourTrav=212, VehHourTrav_ns=212, PassHourTrav=212, PassHourTrav_ns=212, PassUtility=2.5515, PassUtility_ns=2.5515, mean_lambda=nan, revenue_s=254.4, revenue_ns=318.0, Fare_Discount=-0.19999999999999998, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 3
# 18-01-24 13:05:31-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:31-INFO-creating combinations
# 18-01-24 13:05:31-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:31-INFO-Degree 2 	Completed
# 18-01-24 13:05:31-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:31-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:31-INFO-Problem solution: Optimal.
# Total costs for single trips:            283
# reduced by matching to:                  283
# 18-01-24 13:05:31-INFO-Calculations  completed
# 18-01-24 13:05:32-INFO-DotMap(VehHourTrav=283, VehHourTrav_ns=283, PassHourTrav=283, PassHourTrav_ns=283, PassUtility=3.402, PassUtility_ns=3.402, mean_lambda=nan, revenue_s=339.6, revenue_ns=424.5, Fare_Discount=-0.19999999999999996, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 4
# 18-01-24 13:05:32-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:32-INFO-creating combinations
# 18-01-24 13:05:32-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:32-INFO-Degree 2 	Completed
# 18-01-24 13:05:32-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:32-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:32-INFO-Problem solution: Optimal.
# Total costs for single trips:            265
# reduced by matching to:                  265
# 18-01-24 13:05:32-INFO-Calculations  completed
# 18-01-24 13:05:32-INFO-DotMap(VehHourTrav=265, VehHourTrav_ns=265, PassHourTrav=265, PassHourTrav_ns=265, PassUtility=3.183, PassUtility_ns=3.183, mean_lambda=nan, revenue_s=318.0, revenue_ns=397.5, Fare_Discount=-0.2, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 5
# 18-01-24 13:05:32-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:32-INFO-creating combinations
# 18-01-24 13:05:32-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:32-INFO-Degree 2 	Completed
# 18-01-24 13:05:32-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:32-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:32-INFO-Problem solution: Optimal.
# Total costs for single trips:            130
# reduced by matching to:                  130
# 18-01-24 13:05:32-INFO-Calculations  completed
# 18-01-24 13:05:32-INFO-DotMap(VehHourTrav=130, VehHourTrav_ns=130, PassHourTrav=130, PassHourTrav_ns=130, PassUtility=1.5645000000000002, PassUtility_ns=1.5645000000000002, mean_lambda=nan, revenue_s=156.0, revenue_ns=195.0, Fare_Discount=-0.2, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 6
# 18-01-24 13:05:32-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:32-INFO-creating combinations
# 18-01-24 13:05:32-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:32-INFO-Degree 2 	Completed
# 18-01-24 13:05:32-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:32-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:32-INFO-Problem solution: Optimal.
# Total costs for single trips:            195
# reduced by matching to:                  195
# 18-01-24 13:05:32-INFO-Calculations  completed
# 18-01-24 13:05:32-INFO-DotMap(VehHourTrav=195, VehHourTrav_ns=195, PassHourTrav=195, PassHourTrav_ns=195, PassUtility=2.3445, PassUtility_ns=2.3445, mean_lambda=nan, revenue_s=234.0, revenue_ns=292.5, Fare_Discount=-0.2, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 7
# 18-01-24 13:05:33-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:33-INFO-creating combinations
# 18-01-24 13:05:33-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:33-INFO-Degree 2 	Completed
# 18-01-24 13:05:33-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:33-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:33-INFO-Problem solution: Optimal.
# Total costs for single trips:            244
# reduced by matching to:                  244
# 18-01-24 13:05:33-INFO-Calculations  completed
# 18-01-24 13:05:33-INFO-DotMap(VehHourTrav=244, VehHourTrav_ns=244, PassHourTrav=244, PassHourTrav_ns=244, PassUtility=2.934, PassUtility_ns=2.934, mean_lambda=nan, revenue_s=292.8, revenue_ns=366.0, Fare_Discount=-0.19999999999999996, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 8
# 18-01-24 13:05:33-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:33-INFO-creating combinations
# 18-01-24 13:05:33-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:34-INFO-Degree 2 	Completed
# 18-01-24 13:05:34-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:34-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:34-INFO-Problem solution: Optimal.
# Total costs for single trips:            260
# reduced by matching to:                  260
# 18-01-24 13:05:34-INFO-Calculations  completed
# 18-01-24 13:05:34-INFO-DotMap(VehHourTrav=260, VehHourTrav_ns=260, PassHourTrav=260, PassHourTrav_ns=260, PassUtility=3.12, PassUtility_ns=3.12, mean_lambda=nan, revenue_s=312.0, revenue_ns=390.0, Fare_Discount=-0.2, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 9
# 18-01-24 13:05:34-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:34-INFO-creating combinations
# 18-01-24 13:05:34-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:34-INFO-Degree 2 	Completed
# 18-01-24 13:05:34-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:34-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:34-INFO-Problem solution: Optimal.
# Total costs for single trips:            232
# reduced by matching to:                  232
# 18-01-24 13:05:34-INFO-Calculations  completed
# 18-01-24 13:05:34-INFO-DotMap(VehHourTrav=232, VehHourTrav_ns=232, PassHourTrav=232, PassHourTrav_ns=232, PassUtility=2.7855000000000003, PassUtility_ns=2.7855000000000003, mean_lambda=nan, revenue_s=278.40000000000003, revenue_ns=348.0, Fare_Discount=-0.1999999999999999, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.0005 10
# 18-01-24 13:05:34-INFO-Initializing pairwise trip shareability between 1 and 1 trips.
# 18-01-24 13:05:34-INFO-creating combinations
# 18-01-24 13:05:34-INFO-0	 nR*(nR-1)
# 18-01-24 13:05:34-INFO-Degree 2 	Completed
# 18-01-24 13:05:34-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:34-INFO-Matching 1 trips to 1 rides in order to minimize u_veh
# 18-01-24 13:05:34-INFO-Problem solution: Optimal.
# Total costs for single trips:            241
# reduced by matching to:                  241
# 18-01-24 13:05:34-INFO-Calculations  completed
# 18-01-24 13:05:34-INFO-DotMap(VehHourTrav=241, VehHourTrav_ns=241, PassHourTrav=241, PassHourTrav_ns=241, PassUtility=2.8994999999999997, PassUtility_ns=2.8994999999999997, mean_lambda=nan, revenue_s=289.2, revenue_ns=361.5, Fare_Discount=-0.20000000000000004, nR=1, SINGLE=1, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 1
# 18-01-24 13:05:34-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:34-INFO-creating combinations
# 18-01-24 13:05:34-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:34-INFO-Degree 2 	Completed
# 18-01-24 13:05:35-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:35-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:35-INFO-Problem solution: Optimal.
# Total costs for single trips:            288
# reduced by matching to:                  288
# 18-01-24 13:05:35-INFO-Calculations  completed
# 18-01-24 13:05:35-INFO-DotMap(VehHourTrav=288, VehHourTrav_ns=288, PassHourTrav=288, PassHourTrav_ns=288, PassUtility=3.4620000000000006, PassUtility_ns=3.4620000000000006, mean_lambda=nan, revenue_s=345.6, revenue_ns=432.0, Fare_Discount=-0.19999999999999996, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 2
# 18-01-24 13:05:35-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:35-INFO-creating combinations
# 18-01-24 13:05:35-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:35-INFO-Degree 2 	Completed
# 18-01-24 13:05:35-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:35-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:35-INFO-Problem solution: Optimal.
# Total costs for single trips:            288
# reduced by matching to:                  288
# 18-01-24 13:05:35-INFO-Calculations  completed
# 18-01-24 13:05:35-INFO-DotMap(VehHourTrav=288, VehHourTrav_ns=288, PassHourTrav=288, PassHourTrav_ns=288, PassUtility=3.4620000000000006, PassUtility_ns=3.4620000000000006, mean_lambda=nan, revenue_s=345.6, revenue_ns=432.0, Fare_Discount=-0.19999999999999996, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 3
# 18-01-24 13:05:35-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:35-INFO-creating combinations
# 18-01-24 13:05:35-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:35-INFO-Degree 2 	Completed
# 18-01-24 13:05:35-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:35-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:35-INFO-Problem solution: Optimal.
# Total costs for single trips:            269
# reduced by matching to:                  269
# 18-01-24 13:05:35-INFO-Calculations  completed
# 18-01-24 13:05:35-INFO-DotMap(VehHourTrav=269, VehHourTrav_ns=269, PassHourTrav=269, PassHourTrav_ns=269, PassUtility=3.2310000000000003, PassUtility_ns=3.2310000000000003, mean_lambda=nan, revenue_s=322.8, revenue_ns=403.5, Fare_Discount=-0.19999999999999998, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 4
# 18-01-24 13:05:36-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:36-INFO-creating combinations
# 18-01-24 13:05:36-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:36-INFO-Degree 2 	Completed
# 18-01-24 13:05:36-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:36-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:36-INFO-Problem solution: Optimal.
# Total costs for single trips:            228
# reduced by matching to:                  228
# 18-01-24 13:05:36-INFO-Calculations  completed
# 18-01-24 13:05:36-INFO-DotMap(VehHourTrav=228, VehHourTrav_ns=228, PassHourTrav=228, PassHourTrav_ns=228, PassUtility=2.736, PassUtility_ns=2.736, mean_lambda=nan, revenue_s=273.6, revenue_ns=342.0, Fare_Discount=-0.19999999999999993, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 5
# 18-01-24 13:05:36-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:36-INFO-creating combinations
# 18-01-24 13:05:36-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:36-INFO-Degree 2 	Completed
# 18-01-24 13:05:36-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:36-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:36-INFO-Problem solution: Optimal.
# Total costs for single trips:            327
# reduced by matching to:                  327
# 18-01-24 13:05:36-INFO-Calculations  completed
# 18-01-24 13:05:36-INFO-DotMap(VehHourTrav=327, VehHourTrav_ns=327, PassHourTrav=327, PassHourTrav_ns=327, PassUtility=3.936, PassUtility_ns=3.936, mean_lambda=nan, revenue_s=392.40000000000003, revenue_ns=490.5, Fare_Discount=-0.19999999999999993, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 6
# 18-01-24 13:05:37-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:37-INFO-creating combinations
# 18-01-24 13:05:37-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:37-INFO-Degree 2 	Completed
# 18-01-24 13:05:37-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:37-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:37-INFO-Problem solution: Optimal.
# Total costs for single trips:            465
# reduced by matching to:                  465
# 18-01-24 13:05:37-INFO-Calculations  completed
# 18-01-24 13:05:37-INFO-DotMap(VehHourTrav=465, VehHourTrav_ns=465, PassHourTrav=465, PassHourTrav_ns=465, PassUtility=5.595000000000001, PassUtility_ns=5.595000000000001, mean_lambda=nan, revenue_s=558.0, revenue_ns=697.5, Fare_Discount=-0.2, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 7
# 18-01-24 13:05:37-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:37-INFO-creating combinations
# 18-01-24 13:05:37-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:37-INFO-Degree 2 	Completed
# 18-01-24 13:05:37-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:37-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:37-INFO-Problem solution: Optimal.
# Total costs for single trips:            502
# reduced by matching to:                  502
# 18-01-24 13:05:37-INFO-Calculations  completed
# 18-01-24 13:05:37-INFO-DotMap(VehHourTrav=502, VehHourTrav_ns=502, PassHourTrav=502, PassHourTrav_ns=502, PassUtility=6.036, PassUtility_ns=6.036, mean_lambda=nan, revenue_s=602.4, revenue_ns=753.0, Fare_Discount=-0.20000000000000004, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 8
# 18-01-24 13:05:37-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:37-INFO-creating combinations
# 18-01-24 13:05:37-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:38-INFO-Reduction of feasible pairs by 50.00%
# 18-01-24 13:05:38-INFO-Degree 2 	Completed
# 18-01-24 13:05:38-INFO-trips to extend at degree 2 : 2
# 18-01-24 13:05:38-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:05:38-INFO-Degree 3 	Completed
# 18-01-24 13:05:38-INFO-No more trips to exted at degree 3
# 18-01-24 13:05:38-INFO-Matching 2 trips to 4 rides in order to minimize u_veh
# 18-01-24 13:05:38-INFO-Problem solution: Optimal.
# Total costs for single trips:            378
# reduced by matching to:                  300
# 18-01-24 13:05:38-INFO-Calculations  completed
# 18-01-24 13:05:38-INFO-DotMap(VehHourTrav=285, VehHourTrav_ns=378, PassHourTrav=393, PassHourTrav_ns=378, PassUtility=4.3383, PassUtility_ns=4.5435, mean_lambda=0.2063492063492064, revenue_s=453.6, revenue_ns=567.0, Fare_Discount=-0.19999999999999996, nR=2, SINGLE=0, PAIRS=1, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=1.0, fleet_size_nonshared=2.0, fleet_size_shared=1.0, lambda_shared=0.2063492063492064)
# hub1 0.001 9
# 18-01-24 13:05:38-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:38-INFO-creating combinations
# 18-01-24 13:05:38-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:38-INFO-Degree 2 	Completed
# 18-01-24 13:05:38-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:38-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:38-INFO-Problem solution: Optimal.
# Total costs for single trips:            342
# reduced by matching to:                  342
# 18-01-24 13:05:38-INFO-Calculations  completed
# 18-01-24 13:05:38-INFO-DotMap(VehHourTrav=342, VehHourTrav_ns=342, PassHourTrav=342, PassHourTrav_ns=342, PassUtility=4.107, PassUtility_ns=4.107, mean_lambda=nan, revenue_s=410.40000000000003, revenue_ns=513.0, Fare_Discount=-0.19999999999999993, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.001 10
# 18-01-24 13:05:38-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:38-INFO-creating combinations
# 18-01-24 13:05:38-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:38-INFO-Degree 2 	Completed
# 18-01-24 13:05:38-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:38-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:38-INFO-Problem solution: Optimal.
# Total costs for single trips:            277
# reduced by matching to:                  277
# 18-01-24 13:05:38-INFO-Calculations  completed
# 18-01-24 13:05:38-INFO-DotMap(VehHourTrav=277, VehHourTrav_ns=277, PassHourTrav=277, PassHourTrav_ns=277, PassUtility=3.33, PassUtility_ns=3.33, mean_lambda=nan, revenue_s=332.40000000000003, revenue_ns=415.5, Fare_Discount=-0.19999999999999993, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 1
# 18-01-24 13:05:39-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:39-INFO-creating combinations
# 18-01-24 13:05:39-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:39-INFO-Degree 2 	Completed
# 18-01-24 13:05:39-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:39-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:39-INFO-Problem solution: Optimal.
# Total costs for single trips:            336
# reduced by matching to:                  336
# 18-01-24 13:05:39-INFO-Calculations  completed
# 18-01-24 13:05:39-INFO-DotMap(VehHourTrav=336, VehHourTrav_ns=336, PassHourTrav=336, PassHourTrav_ns=336, PassUtility=4.041, PassUtility_ns=4.041, mean_lambda=nan, revenue_s=403.20000000000005, revenue_ns=504.0, Fare_Discount=-0.1999999999999999, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 2
# 18-01-24 13:05:39-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:39-INFO-creating combinations
# 18-01-24 13:05:39-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:39-INFO-Degree 2 	Completed
# 18-01-24 13:05:39-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:39-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:39-INFO-Problem solution: Optimal.
# Total costs for single trips:            305
# reduced by matching to:                  305
# 18-01-24 13:05:39-INFO-Calculations  completed
# 18-01-24 13:05:39-INFO-DotMap(VehHourTrav=305, VehHourTrav_ns=305, PassHourTrav=305, PassHourTrav_ns=305, PassUtility=3.6705, PassUtility_ns=3.6705, mean_lambda=nan, revenue_s=366.0, revenue_ns=457.5, Fare_Discount=-0.2, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 3
# 18-01-24 13:05:40-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:40-INFO-creating combinations
# 18-01-24 13:05:40-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:40-INFO-Degree 2 	Completed
# 18-01-24 13:05:40-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:40-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:40-INFO-Problem solution: Optimal.
# Total costs for single trips:            562
# reduced by matching to:                  562
# 18-01-24 13:05:40-INFO-Calculations  completed
# 18-01-24 13:05:40-INFO-DotMap(VehHourTrav=562, VehHourTrav_ns=562, PassHourTrav=562, PassHourTrav_ns=562, PassUtility=6.7515, PassUtility_ns=6.7515, mean_lambda=nan, revenue_s=674.4000000000001, revenue_ns=843.0, Fare_Discount=-0.1999999999999999, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 4
# 18-01-24 13:05:40-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:40-INFO-creating combinations
# 18-01-24 13:05:40-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:40-INFO-Degree 2 	Completed
# 18-01-24 13:05:40-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:40-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:40-INFO-Problem solution: Optimal.
# Total costs for single trips:            370
# reduced by matching to:                  370
# 18-01-24 13:05:40-INFO-Calculations  completed
# 18-01-24 13:05:40-INFO-DotMap(VehHourTrav=370, VehHourTrav_ns=370, PassHourTrav=370, PassHourTrav_ns=370, PassUtility=4.4445, PassUtility_ns=4.4445, mean_lambda=nan, revenue_s=444.0, revenue_ns=555.0, Fare_Discount=-0.2, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=2.0, fleet_size_shared=2.0, lambda_shared=0)
# hub2 0.001 5
# 18-01-24 13:05:41-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:41-INFO-creating combinations
# 18-01-24 13:05:41-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:41-INFO-Degree 2 	Completed
# 18-01-24 13:05:41-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:41-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:41-INFO-Problem solution: Optimal.
# Total costs for single trips:            256
# reduced by matching to:                  256
# 18-01-24 13:05:41-INFO-Calculations  completed
# 18-01-24 13:05:41-INFO-DotMap(VehHourTrav=256, VehHourTrav_ns=256, PassHourTrav=256, PassHourTrav_ns=256, PassUtility=3.0810000000000004, PassUtility_ns=3.0810000000000004, mean_lambda=nan, revenue_s=307.20000000000005, revenue_ns=384.0, Fare_Discount=-0.19999999999999987, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 6
# 18-01-24 13:05:41-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:41-INFO-creating combinations
# 18-01-24 13:05:41-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:41-INFO-Degree 2 	Completed
# 18-01-24 13:05:41-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:41-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:41-INFO-Problem solution: Optimal.
# Total costs for single trips:            320
# reduced by matching to:                  320
# 18-01-24 13:05:41-INFO-Calculations  completed
# 18-01-24 13:05:41-INFO-DotMap(VehHourTrav=320, VehHourTrav_ns=320, PassHourTrav=320, PassHourTrav_ns=320, PassUtility=3.8475, PassUtility_ns=3.8475, mean_lambda=nan, revenue_s=384.0, revenue_ns=480.0, Fare_Discount=-0.2, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=2.0, fleet_size_shared=2.0, lambda_shared=0)
# hub2 0.001 7
# 18-01-24 13:05:41-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:41-INFO-creating combinations
# 18-01-24 13:05:41-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:41-INFO-Degree 2 	Completed
# 18-01-24 13:05:41-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:41-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:41-INFO-Problem solution: Optimal.
# Total costs for single trips:            410
# reduced by matching to:                  410
# 18-01-24 13:05:41-INFO-Calculations  completed
# 18-01-24 13:05:41-INFO-DotMap(VehHourTrav=410, VehHourTrav_ns=410, PassHourTrav=410, PassHourTrav_ns=410, PassUtility=4.9305, PassUtility_ns=4.9305, mean_lambda=nan, revenue_s=492.0, revenue_ns=615.0, Fare_Discount=-0.2, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 8
# 18-01-24 13:05:42-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:42-INFO-creating combinations
# 18-01-24 13:05:42-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:42-INFO-Degree 2 	Completed
# 18-01-24 13:05:42-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:42-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:42-INFO-Problem solution: Optimal.
# Total costs for single trips:            486
# reduced by matching to:                  486
# 18-01-24 13:05:42-INFO-Calculations  completed
# 18-01-24 13:05:42-INFO-DotMap(VehHourTrav=486, VehHourTrav_ns=486, PassHourTrav=486, PassHourTrav_ns=486, PassUtility=5.841, PassUtility_ns=5.841, mean_lambda=nan, revenue_s=583.2, revenue_ns=729.0, Fare_Discount=-0.19999999999999993, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 9
# 18-01-24 13:05:42-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:42-INFO-creating combinations
# 18-01-24 13:05:42-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:42-INFO-Degree 2 	Completed
# 18-01-24 13:05:42-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:42-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:42-INFO-Problem solution: Optimal.
# Total costs for single trips:            366
# reduced by matching to:                  366
# 18-01-24 13:05:42-INFO-Calculations  completed
# 18-01-24 13:05:42-INFO-DotMap(VehHourTrav=366, VehHourTrav_ns=366, PassHourTrav=366, PassHourTrav_ns=366, PassUtility=4.4025, PassUtility_ns=4.4025, mean_lambda=nan, revenue_s=439.20000000000005, revenue_ns=549.0, Fare_Discount=-0.19999999999999993, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub2 0.001 10
# 18-01-24 13:05:42-INFO-Initializing pairwise trip shareability between 2 and 2 trips.
# 18-01-24 13:05:42-INFO-creating combinations
# 18-01-24 13:05:42-INFO-2	 nR*(nR-1)
# 18-01-24 13:05:42-INFO-Degree 2 	Completed
# 18-01-24 13:05:42-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:42-INFO-Matching 2 trips to 2 rides in order to minimize u_veh
# 18-01-24 13:05:42-INFO-Problem solution: Optimal.
# Total costs for single trips:            437
# reduced by matching to:                  437
# 18-01-24 13:05:42-INFO-Calculations  completed
# 18-01-24 13:05:42-INFO-DotMap(VehHourTrav=437, VehHourTrav_ns=437, PassHourTrav=437, PassHourTrav_ns=437, PassUtility=5.2515, PassUtility_ns=5.2515, mean_lambda=nan, revenue_s=524.4, revenue_ns=655.5, Fare_Discount=-0.20000000000000004, nR=2, SINGLE=2, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 1
# 18-01-24 13:05:43-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:43-INFO-creating combinations
# 18-01-24 13:05:43-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:43-INFO-Degree 2 	Completed
# 18-01-24 13:05:43-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:43-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:43-INFO-Problem solution: Optimal.
# Total costs for single trips:            668
# reduced by matching to:                  668
# 18-01-24 13:05:43-INFO-Calculations  completed
# 18-01-24 13:05:43-INFO-DotMap(VehHourTrav=668, VehHourTrav_ns=668, PassHourTrav=668, PassHourTrav_ns=668, PassUtility=8.037, PassUtility_ns=8.037, mean_lambda=nan, revenue_s=801.6, revenue_ns=1002.0, Fare_Discount=-0.19999999999999998, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 2
# 18-01-24 13:05:43-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:43-INFO-creating combinations
# 18-01-24 13:05:43-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:43-INFO-Reduction of feasible pairs by 100.00%
# 18-01-24 13:05:43-INFO-Degree 2 	Completed
# 18-01-24 13:05:43-INFO-trips to extend at degree 2 : 1
# 18-01-24 13:05:43-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:05:43-INFO-Degree 3 	Completed
# 18-01-24 13:05:43-INFO-No more trips to exted at degree 3
# 18-01-24 13:05:43-INFO-Matching 3 trips to 4 rides in order to minimize u_veh
# 18-01-24 13:05:44-INFO-Problem solution: Optimal.
# Total costs for single trips:            833
# reduced by matching to:                  593
# 18-01-24 13:05:44-INFO-Calculations  completed
# 18-01-24 13:05:44-INFO-DotMap(VehHourTrav=578, VehHourTrav_ns=833, PassHourTrav=865, PassHourTrav_ns=833, PassUtility=9.9684, PassUtility_ns=10.0095, mean_lambda=0.3870967741935484, revenue_s=999.6, revenue_ns=1249.5, Fare_Discount=-0.19999999999999998, nR=3, SINGLE=1, PAIRS=1, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.6666666666666667, fleet_size_nonshared=2.0, fleet_size_shared=1.0, lambda_shared=0.3870967741935484)
# hub1 0.0015 3
# 18-01-24 13:05:44-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:44-INFO-creating combinations
# 18-01-24 13:05:44-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:44-INFO-Degree 2 	Completed
# 18-01-24 13:05:44-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:44-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:44-INFO-Problem solution: Optimal.
# Total costs for single trips:            463
# reduced by matching to:                  463
# 18-01-24 13:05:44-INFO-Calculations  completed
# 18-01-24 13:05:44-INFO-DotMap(VehHourTrav=463, VehHourTrav_ns=463, PassHourTrav=463, PassHourTrav_ns=463, PassUtility=5.5649999999999995, PassUtility_ns=5.5649999999999995, mean_lambda=nan, revenue_s=555.6, revenue_ns=694.5, Fare_Discount=-0.19999999999999996, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 4
# 18-01-24 13:05:44-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:44-INFO-creating combinations
# 18-01-24 13:05:44-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:44-INFO-Degree 2 	Completed
# 18-01-24 13:05:44-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:44-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:44-INFO-Problem solution: Optimal.
# Total costs for single trips:            803
# reduced by matching to:                  803
# 18-01-24 13:05:44-INFO-Calculations  completed
# 18-01-24 13:05:44-INFO-DotMap(VehHourTrav=803, VehHourTrav_ns=803, PassHourTrav=803, PassHourTrav_ns=803, PassUtility=9.6555, PassUtility_ns=9.6555, mean_lambda=nan, revenue_s=963.6, revenue_ns=1204.5, Fare_Discount=-0.19999999999999998, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 5
# 18-01-24 13:05:45-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:45-INFO-creating combinations
# 18-01-24 13:05:45-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:45-INFO-Degree 2 	Completed
# 18-01-24 13:05:45-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:45-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:45-INFO-Problem solution: Optimal.
# Total costs for single trips:            471
# reduced by matching to:                  471
# 18-01-24 13:05:45-INFO-Calculations  completed
# 18-01-24 13:05:45-INFO-DotMap(VehHourTrav=471, VehHourTrav_ns=471, PassHourTrav=471, PassHourTrav_ns=471, PassUtility=5.658, PassUtility_ns=5.658, mean_lambda=nan, revenue_s=565.2, revenue_ns=706.5, Fare_Discount=-0.19999999999999993, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 6
# 18-01-24 13:05:45-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:45-INFO-creating combinations
# 18-01-24 13:05:45-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:45-INFO-Degree 2 	Completed
# 18-01-24 13:05:45-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:45-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:45-INFO-Problem solution: Optimal.
# Total costs for single trips:            636
# reduced by matching to:                  636
# 18-01-24 13:05:45-INFO-Calculations  completed
# 18-01-24 13:05:45-INFO-DotMap(VehHourTrav=636, VehHourTrav_ns=636, PassHourTrav=636, PassHourTrav_ns=636, PassUtility=7.641, PassUtility_ns=7.641, mean_lambda=nan, revenue_s=763.2, revenue_ns=954.0, Fare_Discount=-0.19999999999999996, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 7
# 18-01-24 13:05:46-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:46-INFO-creating combinations
# 18-01-24 13:05:46-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:46-INFO-Degree 2 	Completed
# 18-01-24 13:05:46-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:46-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:46-INFO-Problem solution: Optimal.
# Total costs for single trips:            584
# reduced by matching to:                  584
# 18-01-24 13:05:46-INFO-Calculations  completed
# 18-01-24 13:05:46-INFO-DotMap(VehHourTrav=584, VehHourTrav_ns=584, PassHourTrav=584, PassHourTrav_ns=584, PassUtility=7.023, PassUtility_ns=7.023, mean_lambda=nan, revenue_s=700.8000000000001, revenue_ns=876.0, Fare_Discount=-0.19999999999999993, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=2.0, fleet_size_shared=2.0, lambda_shared=0)
# hub1 0.0015 8
# 18-01-24 13:05:46-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:46-INFO-creating combinations
# 18-01-24 13:05:46-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:46-INFO-Degree 2 	Completed
# 18-01-24 13:05:46-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:46-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:46-INFO-Problem solution: Optimal.
# Total costs for single trips:            651
# reduced by matching to:                  651
# 18-01-24 13:05:46-INFO-Calculations  completed
# 18-01-24 13:05:46-INFO-DotMap(VehHourTrav=651, VehHourTrav_ns=651, PassHourTrav=651, PassHourTrav_ns=651, PassUtility=7.8285, PassUtility_ns=7.8285, mean_lambda=nan, revenue_s=781.2, revenue_ns=976.5, Fare_Discount=-0.19999999999999996, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 9
# 18-01-24 13:05:46-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:47-INFO-creating combinations
# 18-01-24 13:05:47-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:47-INFO-Degree 2 	Completed
# 18-01-24 13:05:47-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:47-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:47-INFO-Problem solution: Optimal.
# Total costs for single trips:            444
# reduced by matching to:                  444
# 18-01-24 13:05:47-INFO-Calculations  completed
# 18-01-24 13:05:47-INFO-DotMap(VehHourTrav=444, VehHourTrav_ns=444, PassHourTrav=444, PassHourTrav_ns=444, PassUtility=5.3355, PassUtility_ns=5.3355, mean_lambda=nan, revenue_s=532.8000000000001, revenue_ns=666.0, Fare_Discount=-0.1999999999999999, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=1.0, fleet_size_shared=1.0, lambda_shared=0)
# hub1 0.0015 10
# 18-01-24 13:05:47-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:47-INFO-creating combinations
# 18-01-24 13:05:47-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:47-INFO-Degree 2 	Completed
# 18-01-24 13:05:47-INFO-No more trips to exted at degree 2
# 18-01-24 13:05:47-INFO-Matching 3 trips to 3 rides in order to minimize u_veh
# 18-01-24 13:05:47-INFO-Problem solution: Optimal.
# Total costs for single trips:            667
# reduced by matching to:                  667
# 18-01-24 13:05:47-INFO-Calculations  completed
# 18-01-24 13:05:47-INFO-DotMap(VehHourTrav=667, VehHourTrav_ns=667, PassHourTrav=667, PassHourTrav_ns=667, PassUtility=8.0175, PassUtility_ns=8.0175, mean_lambda=nan, revenue_s=800.4000000000001, revenue_ns=1000.5, Fare_Discount=-0.1999999999999999, nR=3, SINGLE=3, PAIRS=0, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.0, fleet_size_nonshared=2.0, fleet_size_shared=2.0, lambda_shared=0)
# hub2 0.0015 1
# 18-01-24 13:05:48-INFO-Initializing pairwise trip shareability between 3 and 3 trips.
# 18-01-24 13:05:48-INFO-creating combinations
# 18-01-24 13:05:48-INFO-6	 nR*(nR-1)
# 18-01-24 13:05:48-INFO-Degree 2 	Completed
# ...
# 18-01-24 13:08:28-INFO-trips to extend at degree 2 : 15
# 18-01-24 13:08:28-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:28-INFO-Degree 3 	Completed
# 18-01-24 13:08:28-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:28-INFO-Matching 26 trips to 41 rides in order to minimize u_veh
# 18-01-24 13:08:28-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,037
# reduced by matching to:                4,203
# 18-01-24 13:08:28-INFO-Calculations  completed
# 18-01-24 13:08:28-INFO-DotMap(VehHourTrav=4113, VehHourTrav_ns=5037, PassHourTrav=5173, PassHourTrav_ns=5037, PassUtility=59.60340000000001, PassUtility_ns=60.55200000000001, mean_lambda=0.330689928628073, revenue_s=6044.400000000001, revenue_ns=7555.5, Fare_Discount=-0.19999999999999993, nR=26, SINGLE=14, PAIRS=6, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.46153846153846156, fleet_size_nonshared=6.0, fleet_size_shared=5.0, lambda_shared=0.330689928628073)
# hub1 0.01 9
# 18-01-24 13:08:30-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:30-INFO-creating combinations
# 18-01-24 13:08:30-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:30-INFO-Reduction of feasible pairs by 99.69%
# 18-01-24 13:08:30-INFO-Degree 2 	Completed
# 18-01-24 13:08:30-INFO-trips to extend at degree 2 : 5
# 18-01-24 13:08:30-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:30-INFO-Degree 3 	Completed
# 18-01-24 13:08:30-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:30-INFO-Matching 26 trips to 31 rides in order to minimize u_veh
# 18-01-24 13:08:30-INFO-Problem solution: Optimal.
# Total costs for single trips:          4,842
# reduced by matching to:                4,603
# 18-01-24 13:08:30-INFO-Calculations  completed
# 18-01-24 13:08:30-INFO-DotMap(VehHourTrav=4558, VehHourTrav_ns=4842, PassHourTrav=4890, PassHourTrav_ns=4842, PassUtility=57.84150000000001, PassUtility_ns=58.2105, mean_lambda=0.2586580086580087, revenue_s=5810.400000000001, revenue_ns=7263.0, Fare_Discount=-0.19999999999999993, nR=26, SINGLE=20, PAIRS=3, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.23076923076923073, fleet_size_nonshared=5.0, fleet_size_shared=5.0, lambda_shared=0.2586580086580087)
# hub1 0.01 10
# 18-01-24 13:08:31-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:31-INFO-creating combinations
# 18-01-24 13:08:31-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:31-INFO-Reduction of feasible pairs by 98.92%
# 18-01-24 13:08:31-INFO-Degree 2 	Completed
# 18-01-24 13:08:31-INFO-trips to extend at degree 2 : 13
# 18-01-24 13:08:31-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:31-INFO-Degree 3 	Completed
# 18-01-24 13:08:31-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:31-INFO-Matching 26 trips to 39 rides in order to minimize u_veh
# 18-01-24 13:08:31-INFO-Problem solution: Optimal.
# Total costs for single trips:          4,868
# reduced by matching to:                4,382
# 18-01-24 13:08:31-INFO-Calculations  completed
# 18-01-24 13:08:31-INFO-DotMap(VehHourTrav=4322, VehHourTrav_ns=4868, PassHourTrav=4928, PassHourTrav_ns=4868, PassUtility=58.03200000000001, PassUtility_ns=58.51200000000001, mean_lambda=0.29049611476389714, revenue_s=5841.6, revenue_ns=7302.0, Fare_Discount=-0.19999999999999996, nR=26, SINGLE=18, PAIRS=4, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.3076923076923077, fleet_size_nonshared=7.0, fleet_size_shared=6.0, lambda_shared=0.29049611476389714)
# hub2 0.01 1
# 18-01-24 13:08:33-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:33-INFO-creating combinations
# 18-01-24 13:08:33-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:33-INFO-Reduction of feasible pairs by 98.62%
# 18-01-24 13:08:33-INFO-Degree 2 	Completed
# 18-01-24 13:08:33-INFO-trips to extend at degree 2 : 19
# 18-01-24 13:08:33-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:33-INFO-Degree 3 	Completed
# 18-01-24 13:08:33-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:33-INFO-Matching 26 trips to 45 rides in order to minimize u_veh
# 18-01-24 13:08:33-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,404
# reduced by matching to:                4,550
# 18-01-24 13:08:33-INFO-Calculations  completed
# 18-01-24 13:08:33-INFO-DotMap(VehHourTrav=4445, VehHourTrav_ns=5404, PassHourTrav=5559, PassHourTrav_ns=5404, PassUtility=63.8712, PassUtility_ns=64.9515, mean_lambda=0.2837209302325582, revenue_s=6484.8, revenue_ns=8106.0, Fare_Discount=-0.19999999999999998, nR=26, SINGLE=12, PAIRS=7, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.5384615384615384, fleet_size_nonshared=6.0, fleet_size_shared=4.0, lambda_shared=0.2837209302325582)
# hub2 0.01 2
# 18-01-24 13:08:35-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:35-INFO-creating combinations
# 18-01-24 13:08:35-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:35-INFO-Reduction of feasible pairs by 98.77%
# 18-01-24 13:08:35-INFO-Degree 2 	Completed
# 18-01-24 13:08:35-INFO-trips to extend at degree 2 : 13
# 18-01-24 13:08:35-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:35-INFO-Degree 3 	Completed
# 18-01-24 13:08:35-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:35-INFO-Matching 26 trips to 39 rides in order to minimize u_veh
# 18-01-24 13:08:35-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,286
# reduced by matching to:                4,730
# 18-01-24 13:08:35-INFO-Calculations  completed
# 18-01-24 13:08:35-INFO-DotMap(VehHourTrav=4655, VehHourTrav_ns=5286, PassHourTrav=5371, PassHourTrav_ns=5286, PassUtility=63.1833, PassUtility_ns=63.54899999999999, mean_lambda=0.290491118077325, revenue_s=6343.200000000001, revenue_ns=7929.0, Fare_Discount=-0.1999999999999999, nR=26, SINGLE=16, PAIRS=5, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.3846153846153846, fleet_size_nonshared=6.0, fleet_size_shared=5.0, lambda_shared=0.290491118077325)
# hub2 0.01 3
# 18-01-24 13:08:37-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:37-INFO-creating combinations
# 18-01-24 13:08:37-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:37-INFO-Reduction of feasible pairs by 99.08%
# 18-01-24 13:08:37-INFO-Degree 2 	Completed
# 18-01-24 13:08:37-INFO-trips to extend at degree 2 : 13
# 18-01-24 13:08:37-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:37-INFO-Degree 3 	Completed
# 18-01-24 13:08:37-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:37-INFO-Matching 26 trips to 39 rides in order to minimize u_veh
# 18-01-24 13:08:37-INFO-Problem solution: Optimal.
# Total costs for single trips:          4,909
# reduced by matching to:                3,905
# 18-01-24 13:08:37-INFO-Calculations  completed
# 18-01-24 13:08:37-INFO-DotMap(VehHourTrav=3815, VehHourTrav_ns=4909, PassHourTrav=5025, PassHourTrav_ns=4909, PassUtility=58.047900000000006, PassUtility_ns=59.01449999999999, mean_lambda=0.36076176787639236, revenue_s=5890.8, revenue_ns=7363.5, Fare_Discount=-0.19999999999999998, nR=26, SINGLE=14, PAIRS=6, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.46153846153846156, fleet_size_nonshared=8.0, fleet_size_shared=6.0, lambda_shared=0.36076176787639236)
# hub2 0.01 4
# 18-01-24 13:08:39-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:39-INFO-creating combinations
# 18-01-24 13:08:39-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:39-INFO-Reduction of feasible pairs by 99.08%
# 18-01-24 13:08:39-INFO-Degree 2 	Completed
# 18-01-24 13:08:39-INFO-trips to extend at degree 2 : 15
# 18-01-24 13:08:39-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:39-INFO-Degree 3 	Completed
# 18-01-24 13:08:39-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:39-INFO-Matching 26 trips to 41 rides in order to minimize u_veh
# 18-01-24 13:08:39-INFO-Problem solution: Optimal.
# Total costs for single trips:          6,021
# reduced by matching to:                5,124
# 18-01-24 13:08:39-INFO-Calculations  completed
# 18-01-24 13:08:39-INFO-DotMap(VehHourTrav=5049, VehHourTrav_ns=6021, PassHourTrav=6132, PassHourTrav_ns=6021, PassUtility=71.6118, PassUtility_ns=72.3675, mean_lambda=0.3702022286421791, revenue_s=7225.200000000001, revenue_ns=9031.5, Fare_Discount=-0.19999999999999993, nR=26, SINGLE=16, PAIRS=5, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.3846153846153846, fleet_size_nonshared=7.0, fleet_size_shared=5.0, lambda_shared=0.3702022286421791)
# hub2 0.01 5
# 18-01-24 13:08:41-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:41-INFO-creating combinations
# 18-01-24 13:08:41-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:41-INFO-Reduction of feasible pairs by 99.23%
# 18-01-24 13:08:41-INFO-Degree 2 	Completed
# 18-01-24 13:08:41-INFO-trips to extend at degree 2 : 14
# 18-01-24 13:08:41-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:41-INFO-Degree 3 	Completed
# 18-01-24 13:08:41-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:41-INFO-Matching 26 trips to 40 rides in order to minimize u_veh
# 18-01-24 13:08:41-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,424
# reduced by matching to:                4,837
# 18-01-24 13:08:41-INFO-Calculations  completed
# 18-01-24 13:08:41-INFO-DotMap(VehHourTrav=4792, VehHourTrav_ns=5424, PassHourTrav=5468, PassHourTrav_ns=5424, PassUtility=64.7166, PassUtility_ns=65.2035, mean_lambda=0.4207885304659498, revenue_s=6508.8, revenue_ns=8136.0, Fare_Discount=-0.19999999999999998, nR=26, SINGLE=20, PAIRS=3, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.23076923076923073, fleet_size_nonshared=6.0, fleet_size_shared=5.0, lambda_shared=0.4207885304659498)
# hub2 0.01 6
# 18-01-24 13:08:43-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:43-INFO-creating combinations
# 18-01-24 13:08:43-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:43-INFO-Reduction of feasible pairs by 98.62%
# 18-01-24 13:08:43-INFO-Degree 2 	Completed
# 18-01-24 13:08:43-INFO-trips to extend at degree 2 : 17
# 18-01-24 13:08:43-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:43-INFO-Degree 3 	Completed
# 18-01-24 13:08:43-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:43-INFO-Matching 26 trips to 43 rides in order to minimize u_veh
# 18-01-24 13:08:43-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,105
# reduced by matching to:                4,043
# 18-01-24 13:08:43-INFO-Calculations  completed
# 18-01-24 13:08:43-INFO-DotMap(VehHourTrav=3953, VehHourTrav_ns=5105, PassHourTrav=5192, PassHourTrav_ns=5105, PassUtility=60.08550000000001, PassUtility_ns=61.35300000000001, mean_lambda=0.35649546827794565, revenue_s=6126.0, revenue_ns=7657.5, Fare_Discount=-0.2, nR=26, SINGLE=14, PAIRS=6, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.46153846153846156, fleet_size_nonshared=8.0, fleet_size_shared=6.0, lambda_shared=0.35649546827794565)
# hub2 0.01 7
# 18-01-24 13:08:45-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:45-INFO-creating combinations
# 18-01-24 13:08:45-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:45-INFO-Reduction of feasible pairs by 99.38%
# 18-01-24 13:08:45-INFO-Degree 2 	Completed
# 18-01-24 13:08:45-INFO-trips to extend at degree 2 : 12
# 18-01-24 13:08:45-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:45-INFO-Degree 3 	Completed
# 18-01-24 13:08:45-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:45-INFO-Matching 26 trips to 38 rides in order to minimize u_veh
# 18-01-24 13:08:45-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,335
# reduced by matching to:                4,501
# 18-01-24 13:08:45-INFO-Calculations  completed
# 18-01-24 13:08:45-INFO-DotMap(VehHourTrav=4426, VehHourTrav_ns=5335, PassHourTrav=5419, PassHourTrav_ns=5335, PassUtility=63.4968, PassUtility_ns=64.131, mean_lambda=0.38327205882352944, revenue_s=6402.0, revenue_ns=8002.5, Fare_Discount=-0.2, nR=26, SINGLE=16, PAIRS=5, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.3846153846153846, fleet_size_nonshared=6.0, fleet_size_shared=4.0, lambda_shared=0.38327205882352944)
# hub2 0.01 8
# 18-01-24 13:08:47-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:47-INFO-creating combinations
# 18-01-24 13:08:47-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:47-INFO-Reduction of feasible pairs by 99.38%
# 18-01-24 13:08:47-INFO-Degree 2 	Completed
# 18-01-24 13:08:47-INFO-trips to extend at degree 2 : 7
# 18-01-24 13:08:47-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:47-INFO-Degree 3 	Completed
# 18-01-24 13:08:47-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:47-INFO-Matching 26 trips to 33 rides in order to minimize u_veh
# 18-01-24 13:08:47-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,124
# reduced by matching to:                4,561
# 18-01-24 13:08:47-INFO-Calculations  completed
# 18-01-24 13:08:47-INFO-DotMap(VehHourTrav=4501, VehHourTrav_ns=5124, PassHourTrav=5213, PassHourTrav_ns=5124, PassUtility=60.804300000000005, PassUtility_ns=61.59900000000001, mean_lambda=0.3187995469988675, revenue_s=6148.8, revenue_ns=7686.0, Fare_Discount=-0.19999999999999998, nR=26, SINGLE=18, PAIRS=4, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.3076923076923077, fleet_size_nonshared=6.0, fleet_size_shared=5.0, lambda_shared=0.3187995469988675)
# hub2 0.01 9
# 18-01-24 13:08:49-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:49-INFO-creating combinations
# 18-01-24 13:08:49-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:49-INFO-Reduction of feasible pairs by 99.69%
# 18-01-24 13:08:49-INFO-Degree 2 	Completed
# 18-01-24 13:08:49-INFO-trips to extend at degree 2 : 6
# 18-01-24 13:08:49-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:49-INFO-Degree 3 	Completed
# 18-01-24 13:08:49-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:49-INFO-Matching 26 trips to 32 rides in order to minimize u_veh
# 18-01-24 13:08:49-INFO-Problem solution: Optimal.
# Total costs for single trips:          5,880
# reduced by matching to:                5,206
# 18-01-24 13:08:49-INFO-Calculations  completed
# 18-01-24 13:08:49-INFO-DotMap(VehHourTrav=5146, VehHourTrav_ns=5880, PassHourTrav=5964, PassHourTrav_ns=5880, PassUtility=70.09440000000001, PassUtility_ns=70.647, mean_lambda=0.37361419068736146, revenue_s=7056.0, revenue_ns=8820.0, Fare_Discount=-0.2, nR=26, SINGLE=18, PAIRS=4, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.3076923076923077, fleet_size_nonshared=8.0, fleet_size_shared=6.0, lambda_shared=0.37361419068736146)
# hub2 0.01 10
# 18-01-24 13:08:51-INFO-Initializing pairwise trip shareability between 26 and 26 trips.
# 18-01-24 13:08:51-INFO-creating combinations
# 18-01-24 13:08:51-INFO-650	 nR*(nR-1)
# 18-01-24 13:08:51-INFO-Reduction of feasible pairs by 99.38%
# 18-01-24 13:08:51-INFO-Degree 2 	Completed
# 18-01-24 13:08:51-INFO-trips to extend at degree 2 : 9
# 18-01-24 13:08:51-INFO-At degree 2 feasible extensions found out of 0 searched
# 18-01-24 13:08:51-INFO-Degree 3 	Completed
# 18-01-24 13:08:51-INFO-No more trips to exted at degree 3
# 18-01-24 13:08:51-INFO-Matching 26 trips to 35 rides in order to minimize u_veh
# 18-01-24 13:08:51-INFO-Problem solution: Optimal.
# Total costs for single trips:          6,003
# reduced by matching to:                5,305
# 18-01-24 13:08:51-INFO-Calculations  completed
# 18-01-24 13:08:52-INFO-DotMap(VehHourTrav=5245, VehHourTrav_ns=6003, PassHourTrav=6096, PassHourTrav_ns=6003, PassUtility=71.39760000000001, PassUtility_ns=72.144, mean_lambda=0.34830339321357284, revenue_s=7203.6, revenue_ns=9004.5, Fare_Discount=-0.19999999999999996, nR=26, SINGLE=18, PAIRS=4, TRIPLES=0, QUADRIPLES=0, QUINTETS=0, PLUS5=0, shared_ratio=0.3076923076923077, fleet_size_nonshared=6.0, fleet_size_shared=5.0, lambda_shared=0.34830339321357284)

# %%
results = {}
for num, frac, rep in list(itertools.product([1, 2], [0.0005, 0.001, 0.0015, 0.002, 0.003, 0.005, 0.007, 0.008, 0.01], range(10))):
    results[str((num, frac, rep))] = pd.read_csv('KPI_hub' + str(num) + "_" + str(frac) + "_" + str(rep) + ".csv")["KPI"]
indexes = pd.read_csv('KPI_hub' + str(num) + "_" + str(frac) + "_" + str(rep) + ".csv", index_col=0).index
dfr = pd.DataFrame(results)
dfr.index = indexes
old_indexes = list(dfr.index).copy()
dfr = dfr.append({t: t[1] for t in dfr.columns}, ignore_index=True)
dfr.index = old_indexes + ["hub"]
# print(dfr)
dfr.to_csv('result.csv')

# %%
pd.read_csv('result.csv', header=None).T.to_csv('resultT.csv', header=False, index=False)

# %%
ExMAS.utils.plot_demand(inData, params)

# %% [markdown]
# # plotting #

# %%
dfT = pd.read_csv('resultT.csv', index_col=0) # discount 0.2

dfT['del_VehHourTrav']=abs(dfT['VehHourTrav']-dfT['VehHourTrav_ns'])/dfT['VehHourTrav_ns']           # KPI1: vehicle hours reduction
dfT['del_PassUtility']=abs((dfT['PassUtility']-dfT['PassUtility_ns'])/dfT['PassUtility_ns'])      # KPI2: travellers utility gains
dfT['Occupancy']=dfT['PassHourTrav']/dfT['VehHourTrav']                                       # KPI4: occupancy
dfT['del_PassHourTrav']=abs((dfT['PassHourTrav']-dfT['PassHourTrav_ns'])/dfT['PassHourTrav_ns'])  # KPI5: passenger hours increase
dfT['del_fleet_size']=abs((dfT['fleet_size_shared']-dfT['fleet_size_nonshared'])/dfT['fleet_size_nonshared'])  # KPI6: potential fleet size reduction                  
                  
dfT['frac'] = round((dfT['nR'] / len(df)),4)

# %%
from scipy.optimize import curve_fit
import seaborn as sns
import matplotlib.pyplot as plt
import scienceplots
import matplotlib.patches as mpatches
from cycler import cycler


def plot_log_fit(x,y,ax, color = 'black'):
    popt, pcov = curve_fit(lambda t, a, b, c: a * np.log(b * t) + c, x,y )
    a = popt[0]
    b = popt[1]
    c = popt[2]
    x_fitted = np.linspace(np.min(x), np.max(x), 100)
    y_fitted = a * np.log(b * x_fitted) + c
    ax.plot(x_fitted, y_fitted, lw = 2, color = color)

fig, axes = plt.subplots(2,3, figsize = (12,8))
axes = axes.flatten()

ax=axes[0]
to_plot = dfT[(dfT.hub == 1)]
# sns.regplot(data = to_plot, x = 'frac', y = 'del_VehHourTrav', 
#             scatter_kws = {'s':0.3, 'alpha':0.3, 'color':'lightblue'}, ax = ax, 
#             line_kws = {'lw':0}, ci =None)
plot_log_fit(to_plot.frac, to_plot.del_VehHourTrav, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_VehHourTrav.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
# sns.regplot(data = to_plot, x = 'frac', y = 'del_VehHourTrav', 
#             scatter_kws = {'s':0.3, 'alpha':0.3, 'color':'lightgreen'}, ax = ax, 
#             line_kws = {'lw':0}, ci =None)
plot_log_fit(to_plot.frac, to_plot.del_VehHourTrav, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).del_VehHourTrav.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$\Delta T_v$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Vehicle hours reduction", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')


ax=axes[1]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.del_PassUtility, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_PassUtility.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.del_PassUtility, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).del_PassUtility.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$\Delta U_p$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Travellers utility gains", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')


ax=axes[2]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.shared_ratio, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_PassUtility.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.shared_ratio, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).shared_ratio.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$S$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Share of pooling", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')

ax=axes[3]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.Occupancy, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).Occupancy.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.Occupancy, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).Occupancy.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$O$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Occupancy", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')

ax=axes[4]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.del_PassHourTrav, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_PassHourTrav.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.del_PassHourTrav, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).del_PassHourTrav.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$\Delta T_p$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Passenger hours increase", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')

ax=axes[5]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.del_fleet_size, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_fleet_size.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.del_fleet_size, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).del_fleet_size.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$\Delta F$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Potential fleet reduction", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')

plt.subplots_adjust(left=0,
                    bottom=0.2, 
                    right=1, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.45)

# plt.savefig('WK_2hubs_discount0.2.jpg', dpi=300)

# %%
from scipy.optimize import curve_fit
import seaborn as sns
import matplotlib.pyplot as plt
import scienceplots
import matplotlib.patches as mpatches
from cycler import cycler


def plot_log_fit(x,y,ax, color = 'black'):
    popt, pcov = curve_fit(lambda t, a, b, c: a * np.log(b * t) + c, x,y )
    a = popt[0]
    b = popt[1]
    c = popt[2]
    x_fitted = np.linspace(np.min(x), np.max(x), 100)
    y_fitted = a * np.log(b * x_fitted) + c
    ax.plot(x_fitted, y_fitted, lw = 2, color = color)

fig, axes = plt.subplots(2,3, figsize = (12,8))
axes = axes.flatten()

ax=axes[0]
to_plot = dfT[(dfT.hub == 1)]
# sns.regplot(data = to_plot, x = 'frac', y = 'del_VehHourTrav', 
#             scatter_kws = {'s':0.3, 'alpha':0.3, 'color':'lightblue'}, ax = ax, 
#             line_kws = {'lw':0}, ci =None)
plot_log_fit(to_plot.frac, to_plot.del_VehHourTrav, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_VehHourTrav.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
# sns.regplot(data = to_plot, x = 'frac', y = 'del_VehHourTrav', 
#             scatter_kws = {'s':0.3, 'alpha':0.3, 'color':'lightgreen'}, ax = ax, 
#             line_kws = {'lw':0}, ci =None)
plot_log_fit(to_plot.frac, to_plot.del_VehHourTrav, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).del_VehHourTrav.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$\Delta T_v$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Vehicle hours reduction", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')


ax=axes[1]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.del_PassUtility, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_PassUtility.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.del_PassUtility, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).del_PassUtility.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$\Delta U_p$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Travellers utility gains", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')


ax=axes[2]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.shared_ratio, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).del_PassUtility.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.shared_ratio, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).shared_ratio.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$S$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Share of pooling", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')

ax=axes[3]
to_plot = dfT[(dfT.hub == 1)]
plot_log_fit(to_plot.frac, to_plot.Occupancy, ax, 'blue')
to_plot = dfT[(dfT.hub == 1)].groupby(dfT.frac).Occupancy.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='blue', marker = 'o')

to_plot = dfT[(dfT.hub == 2)]
plot_log_fit(to_plot.frac, to_plot.Occupancy, ax, 'green')
to_plot = dfT[(dfT.hub == 2)].groupby(dfT.frac).Occupancy.mean()
ax.scatter(x=to_plot.index,y=to_plot.values, s = 4, color='green', marker = 'o')

ax.set_ylabel("$O$", fontsize=10)
ax.set_xlabel("Fraction of demand", fontsize=10)
ax.set_title("Occupancy", fontsize=10, fontweight='normal')
legend_dict = { 'hub1': 'blue', 'hub2' : 'green'}
patchList = []
for key in legend_dict:
        data_key = mpatches.Patch(color=legend_dict[key], label=key)
        patchList.append(data_key)

ax.legend(handles=patchList, loc='upper left')



plt.subplots_adjust(left=0,
                    bottom=0.2, 
                    right=1, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.45)
